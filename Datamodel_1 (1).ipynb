# %% [markdown]
# ## Data model copy 1

# %% [markdown]
# # Predictive Modeling Example

# %% [markdown]
# ## Step 1: Import the libraries we will use in this notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

np.random.seed(1) # set this to ensure the results are repeatable.

# %% [markdown]
# ## Step 2: Load the given data that we will model

# %%
df = pd.read_csv('./data/modelcopy1.csv')

df.head(3)
# Out:
#     input     target
# 0  116.24  34.496575
# 1   93.88 -31.666154
# 2   94.72  20.858654

# %% [markdown]
# Seperate out the input m(X) and the target (y)

# %%
X=df[['input']]
y=df[['target']]

# %% [markdown]
# ## Step 3: Explore the given data
#
# Often we will do much more than this, but at least look at things using a scatterplot

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')

ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Fit the model
#
# Fit the linear regression model to the dataset

# %%
lin_reg=LinearRegression()
_ = lin_reg.fit(np.sin(X),y)

# OR, we could combine the two lines above to one as follows...
#lin_reg = LinearRegression().fit(X,y)

# %% [markdown]
# ## Step 5: Analyze the linear regression model's performance

# %% [markdown]
# Visualize the linear regression model results

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')
ax.scatter(X,lin_reg.predict(np.sin(X)),color='blue')

ax.set_title('Linear Regression')
ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %%
b0 = lin_reg.intercept_[0]
b1 = lin_reg.coef_[0][0]
r2 = lin_reg.score(X, y)
print(f"Y = {b0:.2f} + {b1:.2f}sin(x)")
print(f"R^2: {lin_reg.score(np.sin(X), y):.3f}")
# Out:
# Y = 25.37 + 31.90sin(x)
# R^2: 0.381

# %% [markdown]
# # Analysis

# %% [markdown]
# After we read the data from the data gen model, we plot the input and target columns

# %% [markdown]
# Based on the plot, then we fit a linear regression model with sin function based on the observation from the plot.

# %% [markdown]
# We can observe that, our fitted model how it matches with the existing plotted information and we calculate the R-square value, from the observed r square value which is 0.38 which is very low and a bad model for the current data.
