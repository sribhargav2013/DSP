# %% [markdown]
# ## Data model copy 2

# %% [markdown]
# # Predictive Modeling Example

# %% [markdown]
# ## Step 1: Import the libraries we will use in this notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

np.random.seed(1) # set this to ensure the results are repeatable.

# %% [markdown]
# ## Step 2: Load the given data that we will model

# %%
df = pd.read_csv('./data/modelcopy2.csv')

df.head(3)
# Out:
#     input     target
# 0  116.24  33.926575
# 1   93.88 -25.056154
# 2   94.72  10.958654

# %% [markdown]
# Seperate out the input m(X) and the target (y)

# %%
X=df[['input']]
y=df[['target']]

# %% [markdown]
# ## Step 3: Explore the given data
#
# Often we will do much more than this, but at least look at things using a scatterplot

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')

ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Fit the model
#
# Fit the linear regression model to the dataset

# %%
lin_reg=LinearRegression()
_ = lin_reg.fit(np.sin(X),y)

# OR, we could combine the two lines above to one as follows...
#lin_reg = LinearRegression().fit(X,y)

# %% [markdown]
# ## Step 5: Analyze the linear regression model's performance

# %% [markdown]
# Visualize the linear regression model results

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')
ax.scatter(X,lin_reg.predict(np.sin(X)),color='blue')

ax.set_title('Linear Regression')
ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %%
b0 = lin_reg.intercept_[0]
b1 = lin_reg.coef_[0][0]
r2 = lin_reg.score(X, y)
print(f"Y = {b0:.2f} + {b1:.2f}sin(x)")
print(f"R^2: {lin_reg.score(np.sin(X), y):.3f}")
# Out:
# Y = 27.36 + 30.52sin(x)
# R^2: 0.371

# %% [markdown]
# ## Analysis

# %% [markdown]
#  In this model, after we read the data and generate a plot, and based on the information of the scattered data, we have fitted a linear regression model with sin function

# %% [markdown]
# In this model, we have considered a data with very few observations

# %% [markdown]
# Even though we have less number of observations  compared to our previous notebook, the model doesnt fit well, as we can see the graph and also the R squared value which is 0.37 and indicates that this is not a good fit and a bad model. Comparing with previous notebook still the sin linear regression doesnt seem a good option.

# %% [markdown]
# This idicates that this relationship is not good for the linear regression that we had fitted and we might have to figure out any alternative models for this problem
